# %% [markdown]
# ## Fields detials
#
# 1.  Gender - sexual representation ( Male or Female)
# 2.  Age - in years
# 3.  Height - in meters
# 4.  Weight - in Kgs
# 5.  family_history_with_overweight - YES or NO type
# 6.  FAVC - Frequent consumption of high caloric food
# 7.  FCVC -  Frequency of consumption of vegetables
# 8.  NCP - Number of Main Meals
# 9.  CAEC - Consumption of Food between Meals
# 10. SMOKE - YES or NO type
# 11. CH2O - Consumption of Water Daily
# 12. SCC - Calories Consumption monitoring
# 13. FAF - Physical Activity Frequency
# 14. TUE - Time Using Technology (hours)
# 15. CALC - Consumption of Alcohol
# 16. MTRANS - Mode of Transportation Used Daily
# 17. NObeyesdad - Targer Feature

# %% [markdown]
# ### 1. Import required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from dataclasses import dataclass
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier
)
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
import joblib

# %% [markdown]
# ### 2. Read the dataframe

# %%
file_path = os.path.join(os.getcwd(), 'train.csv')
df = pd.read_csv(file_path)

# %% [markdown]
# ## 3. EDA
# ### 3.1 Handling missing values
# ### 3.2 Handling out liers
# ### 3.3 Handling duplicates

# %%
df.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# ### 3.0.0 Identify the column types

# %%
df.drop(columns=['id'], axis=1, inplace=True)
columns = df.columns
cat_columns = [col for col in columns if df[col].dtype == 'O' or df[col].nunique() < (df.shape[0] // df[col].nunique())]
num_columns = [col for col in columns if df[col].dtype != 'O' and df[col].nunique() > (df.shape[0] // df[col].nunique())]
print('Number of columns present in the dataframe: ', len(columns))
print('Number of catagorical columns present in the dataframe: ', len(cat_columns))
print('Number of numarical columns present in the dataframe: ', len(num_columns))
# Out:
# Number of columns present in the dataframe:  17
# Number of catagorical columns present in the dataframe:  9
# Number of numarical columns present in the dataframe:  8

# %% [markdown]
# ### 3.0.1 List out the number of unique values present in each columns

# %%
for col in columns:
  print(f"{col} : {df[col].nunique()}")
# Out:
# Gender : 2
# Age : 1703
# Height : 1833
# Weight : 1979
# family_history_with_overweight : 2
# FAVC : 2
# FCVC : 934
# NCP : 689
# CAEC : 4
# SMOKE : 2
# CH2O : 1506
# SCC : 2
# FAF : 1360
# TUE : 1297
# CALC : 3
# MTRANS : 5
# NObeyesdad : 7

# %% [markdown]
# ### 3.0.2 List the unique values in catagorical columns

# %%
for col in cat_columns:
  print(f"{col} : {df[col].unique()}")
# Out:
# Gender : ['Male' 'Female']
# family_history_with_overweight : ['yes' 'no']
# FAVC : ['yes' 'no']
# CAEC : ['Sometimes' 'Frequently' 'no' 'Always']
# SMOKE : ['no' 'yes']
# SCC : ['no' 'yes']
# CALC : ['Sometimes' 'no' 'Frequently']
# MTRANS : ['Public_Transportation' 'Automobile' 'Walking' 'Motorbike' 'Bike']
# NObeyesdad : ['Overweight_Level_II' 'Normal_Weight' 'Insufficient_Weight'
#  'Obesity_Type_III' 'Obesity_Type_II' 'Overweight_Level_I'
#  'Obesity_Type_I']

# %%
df['MTRANS'].replace({
    'Bike': 'Bicycle',
    'Motorbike': '2 or 4 wheeler',
    'Public_Transportation': '2 or 4 wheeler',
    'Automobile': '2 or 4 wheeler',
}, inplace=True)
print(f"unique values in MTRANS is {df['MTRANS'].unique()}")
# Out:
# unique values in MTRANS is ['2 or 4 wheeler' 'Walking' 'Bicycle']
# C:\Users\namac\AppData\Local\Temp\ipykernel_4424\3858041126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MTRANS'].replace({

# %% [markdown]
# ### 3.1.0 List the number of missing values in the dataframe

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# ### 3.2.0 Check the outliers in the dataframe

# %%
df.describe()
# Out:
#                 Age        Height        Weight          FCVC           NCP  \
# count  20758.000000  20758.000000  20758.000000  20758.000000  20758.000000
# mean      23.841804      1.700245     87.887768      2.445908      2.761332
# std        5.688072      0.087312     26.379443      0.533218      0.705375
# min       14.000000      1.450000     39.000000      1.000000      1.000000
# 25%       20.000000      1.631856     66.000000      2.000000      3.000000
# 50%       22.815416      1.700000     84.064875      2.393837      3.000000
# 75%       26.000000      1.762887    111.600553      3.000000      3.000000
# max       61.000000      1.975663    165.057269      3.000000      4.000000
#
#                CH2O           FAF           TUE
# count  20758.000000  20758.000000  20758.000000
# mean       2.029418      0.981747      0.616756
# std        0.608467      0.838302      0.602113
# min        1.000000      0.000000      0.000000
# 25%        1.792022      0.008013      0.000000
# 50%        2.000000      1.000000      0.573887
# 75%        2.549617      1.587406      1.000000
# max        3.000000      3.000000      2.000000

# %% [markdown]
# ### 3.3.0 Check the duplicates

# %%
print(f"number duplicate records in the dataframe is {df.duplicated().sum()}")
# Out:
# number duplicate records in the dataframe is 5

# %%
print("duplicate recordes")
df[df.duplicated()]
# Out:
# duplicate recordes
#        Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 8165   Female  19.0    1.52    42.0                             no  yes   3.0
# 9127     Male  23.0    1.70    75.0                            yes  yes   2.0
# 12780  Female  40.0    1.56    80.0                            yes  yes   2.0
# 14194    Male  19.0    1.82    72.0                            yes  yes   2.0
# 17376  Female  40.0    1.56    80.0                            yes  yes   2.0
#
#        NCP        CAEC SMOKE  CH2O SCC  FAF  TUE       CALC          MTRANS  \
# 8165   1.0   Sometimes    no   1.0  no  0.0  0.0  Sometimes  2 or 4 wheeler
# 9127   3.0  Frequently    no   2.0  no  1.0  1.0  Sometimes  2 or 4 wheeler
# 12780  3.0   Sometimes    no   1.0  no  0.0  0.0         no  2 or 4 wheeler
# 14194  3.0   Sometimes    no   2.0  no  1.0  1.0  Sometimes  2 or 4 wheeler
# 17376  3.0   Sometimes    no   2.0  no  2.0  0.0  Sometimes  2 or 4 wheeler
#
#                 NObeyesdad
# 8165   Insufficient_Weight
# 9127    Overweight_Level_I
# 12780       Obesity_Type_I
# 14194        Normal_Weight
# 17376       Obesity_Type_I

# %% [markdown]
# ### 3.3.1 Delete the duplicate recordes

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## 4. Feature engineering
# ### 4.1 Create preprocesser pipeline

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class MyLabelEncoder(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoders = {}

    def fit(self, X, y=None):
        for column in X.columns:
            self.encoders[column] = LabelEncoder().fit(X[column])
        return self

    def transform(self, X):
        X_encoded = X.copy()
        for column, encoder in self.encoders.items():
            X_encoded[column] = encoder.transform(X[column])
        return X_encoded

# %%
cat_pipeline = Pipeline(
    steps=[
        ('Encoder', MyLabelEncoder()),
        ('Scaler', StandardScaler())
    ]
)

preprocessor_pipeline = ColumnTransformer([
    ('cat_pipeline', cat_pipeline, cat_columns[:-1]),
    ('Scaler', StandardScaler(), num_columns)
], remainder='passthrough')

# %% [markdown]
# ### split the dataset using train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:, :-1], df.iloc[:, -1], test_size=0.2, random_state=42)

# %% [markdown]
# ### encode the target

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %%
x_train[:5]
# Out:
#        Gender        Age    Height      Weight family_history_with_overweight  \
# 10901    Male  23.000000  1.650000   62.000000                             no
# 15207    Male  21.000000  1.650000   70.000000                             no
# 12022  Female  25.919571  1.610225  102.249831                            yes
# 13780    Male  21.125836  1.650000   80.000000                            yes
# 14306  Female  18.000000  1.716545   52.000000                            yes
#
#       FAVC  FCVC  NCP        CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 10901  yes   3.0  3.0   Sometimes    no  2.000000  no  1.000000  1.000000
# 15207  yes   2.0  1.0          no    no  2.000000  no  1.000000  0.000000
# 12022  yes   3.0  3.0   Sometimes    no  1.120213  no  1.999836  0.813235
# 13780  yes   2.0  3.0   Sometimes    no  2.000000  no  2.708250  1.000000
# 14306  yes   2.0  3.0  Frequently    no  2.000000  no  0.827502  1.817146
#
#             CALC          MTRANS
# 10901  Sometimes  2 or 4 wheeler
# 15207  Sometimes  2 or 4 wheeler
# 12022  Sometimes  2 or 4 wheeler
# 13780         no  2 or 4 wheeler
# 14306         no  2 or 4 wheeler

# %% [markdown]
# ### fit the data in preprocessor pipeline for save the preprocessor

# %%
preprocessor_pipeline.fit(x_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat_pipeline',
#                                  Pipeline(steps=[('Encoder', MyLabelEncoder()),
#                                                  ('Scaler', StandardScaler())]),
#                                  ['Gender', 'family_history_with_overweight',
#                                   'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC',
#                                   'MTRANS']),
#                                 ('Scaler', StandardScaler(),
#                                  ['Age', 'Height', 'Weight', 'FCVC', 'NCP',
#                                   'CH2O', 'FAF', 'TUE'])])

# %% [markdown]
# ### save the preprocessor_pipeline

# %%
def save_object(file_path, object_to_save):
  try:
    joblib.dump(object_to_save, file_path)
  except Exception as e:
        raise

# %%
preprocessor_path = os.path.join(os.getcwd(), 'preprocessor.pkl')
save_object(
    file_path = preprocessor_path,
    object_to_save = preprocessor_pipeline
)

# %% [markdown]
# ### Reload the model

# %%
preprocessor = joblib.load( preprocessor_path)

# %%
# preprocess the x_train and x_test
x_test = preprocessor.transform(x_test)
x_train = preprocessor.transform(x_train)

# %%
def evaluate_model(x_train, x_test, y_train, y_test, models, params):
    try:
        report = {
            'model': [],
            'train accuracy': [],
            'test accuracy': []
        }

        for i in range(len(list(models))):
            # initiate model
            model = list(models.values())[i]
            para = params[list(models.keys())[i]]

            gs = GridSearchCV(model, para, cv=3)
            gs.fit(x_train, y_train)

            model.set_params(**gs.best_params_)
            model.fit(x_train, y_train)

            # make predictions
            y_train_pred = model.predict(x_train)
            y_test_pred = model.predict(x_test)

            # calculate accuracy
            train_accuracy = accuracy_score(y_train, y_train_pred)
            test_accuracy = accuracy_score(y_test, y_test_pred)

            # append the accuracies to the report
            report['model'].append(list(models.keys())[i])
            report['train accuracy'].append(train_accuracy)
            report['test accuracy'].append(test_accuracy)

        return report

    except Exception as e:
        raise

# %%
@dataclass
class ModelTrainerConfig:
    trained_model_file_path = os.path.join(os.getcwd(), 'model.pkl')

class ModelTrainer:
    def __init__(self):
        self.model_trainer_config = ModelTrainerConfig()

    def initiate_model_trainer(self, x_train, x_test, y_train, y_test):
        try:
            models = {
                'Decision Tree': DecisionTreeClassifier(),
                'Ada Boost': AdaBoostClassifier(),
                'Gradient Boost': GradientBoostingClassifier(),
                'Random Forest': RandomForestClassifier(),
                'KNeighbors': KNeighborsClassifier(),
                'Cat Boost': CatBoostClassifier(),
                'XGBoost': XGBClassifier()
            }

            model_params = {
                "Decision Tree": {
                    'criterion':['gini', 'entropy'],
                    'splitter':['best','random'],
                    'max_depth':[None, 5, 10, 15, 20],
                },
                "Ada Boost":{
                    'learning_rate':[0.1, 0.01, 0.5, 0.001],
                    'n_estimators': [50, 100, 200, 500]
                },
                "Gradient Boost":{
                    'learning_rate':[0.1, 0.01, 0.05, 0.001],
                    'subsample':[0.6, 0.7, 0.75, 0.8, 0.85, 0.9],
                    'n_estimators': [50, 100, 200, 500]
                },
                "Random Forest":{
                    'n_estimators': [50, 100, 200, 500],
                    'max_depth':[None, 5, 10, 15, 20],
                    'criterion':['gini', 'entropy']
                },
                'KNeighbors': {
                    'n_neighbors': [3, 5, 7, 9],
                    'weights': ['uniform', 'distance'],
                    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
                },
                "Cat Boost":{
                    'depth': [6, 8, 10],
                    'learning_rate': [0.01, 0.05, 0.1],
                    'iterations': [30, 50, 100]
                },
                "XGBoost":{
                    'learning_rate':[0.1, 0.01, 0.05, 0.001],
                    'n_estimators': [50, 100, 200, 500]
                },
            }

            # get models evaluation report
            model_report: dict = evaluate_model(x_train=x_train, x_test=x_test, y_train=y_train, y_test=y_test, models=models, params=model_params)

            report_df = pd.DataFrame(model_report, index=None)
            print('model report: \n', report_df)

            best_train_record = report_df[report_df['train accuracy'] == report_df['train accuracy'].max()]
            print('best model based on train accuracy: \n', best_train_record)

            best_test_record = report_df[report_df['test accuracy'] == report_df['test accuracy'].max()]
            print('best model based on test accuracy: \n', best_test_record)

            report_df['over_all_score'] = (report_df['train accuracy'] + report_df['test accuracy']) / 2
            record_above_nine = report_df[(report_df['train accuracy'] > 0.9) & (report_df['test accuracy'] > 0.9)]
            best_model_record = record_above_nine[record_above_nine['over_all_score'] == record_above_nine['over_all_score'].max()]
            print('overall best model: \n', best_model_record)

            best_model_score = best_model_record['test accuracy'].iloc[0]
            best_model_name = best_model_record['model'].iloc[0]
            best_model = models[best_model_name]

            if best_model_score < 0.6:
                print('Best model not found')
                return

            print(f"best model score: {best_model_score}")
            print(f"best model name: {best_model_name}")

            save_object(
                file_path = self.model_trainer_config.trained_model_file_path,
                object_to_save = best_model
            )

            return self.model_trainer_config.trained_model_file_path

        except Exception as e:
            raise

# %%
model_trainer = ModelTrainer()
best_model_path = model_trainer.initiate_model_trainer(
    x_train = x_train,
    x_test = x_test,
    y_train = y_train,
    y_test = y_test
)
# Out:
# 27:	learn: 0.4088853	total: 9.14s	remaining: 23.5s
# 28:	learn: 0.4005545	total: 9.46s	remaining: 23.2s
# 29:	learn: 0.3930602	total: 9.78s	remaining: 22.8s
# 30:	learn: 0.3870922	total: 10.1s	remaining: 22.5s
# 31:	learn: 0.3819253	total: 10.4s	remaining: 22.2s
# 32:	learn: 0.3761875	total: 10.8s	remaining: 21.9s
# 33:	learn: 0.3702846	total: 11.1s	remaining: 21.5s
# 34:	learn: 0.3652282	total: 11.4s	remaining: 21.2s
# 35:	learn: 0.3599089	total: 11.7s	remaining: 20.9s
# 36:	learn: 0.3545472	total: 12.1s	remaining: 20.5s
# 37:	learn: 0.3502257	total: 12.4s	remaining: 20.2s
# 38:	learn: 0.3454124	total: 12.7s	remaining: 19.9s
# 39:	learn: 0.3416854	total: 13s	remaining: 19.6s
# 40:	learn: 0.3375486	total: 13.4s	remaining: 19.2s
# 41:	learn: 0.3336940	total: 13.7s	remaining: 18.9s
# 42:	learn: 0.3294522	total: 14s	remaining: 18.6s
# 43:	learn: 0.3259640	total: 14.3s	remaining: 18.3s
# 44:	learn: 0.3218684	total: 14.7s	remaining: 17.9s
# 45:	learn: 0.3188478	total: 15s	remaining: 17.6s
# 46:	learn: 0.3156998	total: 15.3s	remaining: 17.3s
# 47:	learn: 0.3129004	total: 15.7s	remaining: 17s
# 48:	learn: 0.3100584	total: 16s	remaining: 16.6s
# 49:	learn: 0.3069473	total: 16.3s	remaining: 16.3s
# 50:	learn: 0.3041381	total: 16.6s	remaining: 16s
# 51:	learn: 0.3011166	total: 16.9s	remaining: 15.6s
# 52:	learn: 0.2987338	total: 17.2s	remaining: 15.3s
# 53:	learn: 0.2964369	total: 17.6s	remaining: 15s
# 54:	learn: 0.2948099	total: 17.9s	remaining: 14.7s
# 55:	learn: 0.2924466	total: 18.3s	remaining: 14.4s
# 56:	learn: 0.2900274	total: 18.6s	remaining: 14.1s
# 57:	learn: 0.2879343	total: 18.9s	remaining: 13.7s
# 58:	learn: 0.2860801	total: 19.3s	remaining: 13.4s
# 59:	learn: 0.2835027	total: 19.6s	remaining: 13.1s
# 60:	learn: 0.2817391	total: 19.9s	remaining: 12.7s
# 61:	learn: 0.2801476	total: 20.2s	remaining: 12.4s
# 62:	learn: 0.2777816	total: 20.6s	remaining: 12.1s
# 63:	learn: 0.2755736	total: 20.9s	remaining: 11.7s
# 64:	learn: 0.2738963	total: 21.2s	remaining: 11.4s
# 65:	learn: 0.2723655	total: 21.5s	remaining: 11.1s
# 66:	learn: 0.2709224	total: 21.8s	remaining: 10.8s
# 67:	learn: 0.2690754	total: 22.2s	remaining: 10.4s
# 68:	learn: 0.2673951	total: 22.5s	remaining: 10.1s
# 69:	learn: 0.2656404	total: 22.8s	remaining: 9.78s
# 70:	learn: 0.2639967	total: 23.2s	remaining: 9.46s
# 71:	learn: 0.2621365	total: 23.5s	remaining: 9.13s
# 72:	learn: 0.2606223	total: 23.8s	remaining: 8.8s
# 58:	learn: 0.3130081	total: 6.11s	remaining: 4.24s
# 59:	learn: 0.3116102	total: 6.2s	remaining: 4.14s
# 60:	learn: 0.3100807	total: 6.31s	remaining: 4.03s
# 61:	learn: 0.3085538	total: 6.41s	remaining: 3.93s
# 62:	learn: 0.3072806	total: 6.51s	remaining: 3.82s
# 63:	learn: 0.3059441	total: 6.62s	remaining: 3.72s
# 64:	learn: 0.3042843	total: 6.72s	remaining: 3.62s
# 65:	learn: 0.3028163	total: 6.83s	remaining: 3.52s
# 66:	learn: 0.3008642	total: 6.93s	remaining: 3.42s
# 67:	learn: 0.2993792	total: 7.04s	remaining: 3.31s
# 68:	learn: 0.2978312	total: 7.15s	remaining: 3.21s
# 69:	learn: 0.2967528	total: 7.25s	remaining: 3.11s
# 70:	learn: 0.2955269	total: 7.35s	remaining: 3s
# 71:	learn: 0.2941288	total: 7.45s	remaining: 2.9s
# 72:	learn: 0.2925628	total: 7.55s	remaining: 2.79s
# 73:	learn: 0.2914769	total: 7.65s	remaining: 2.69s
# 74:	learn: 0.2900482	total: 7.76s	remaining: 2.58s
# 75:	learn: 0.2885774	total: 7.86s	remaining: 2.48s
# 76:	learn: 0.2873565	total: 7.96s	remaining: 2.38s
# 77:	learn: 0.2865026	total: 8.09s	remaining: 2.28s
# 78:	learn: 0.2852725	total: 8.18s	remaining: 2.17s
# 79:	learn: 0.2843364	total: 8.28s	remaining: 2.07s
# 80:	learn: 0.2831600	total: 8.39s	remaining: 1.97s
# 81:	learn: 0.2822637	total: 8.49s	remaining: 1.86s
# 82:	learn: 0.2814541	total: 8.59s	remaining: 1.76s
# 83:	learn: 0.2809084	total: 8.7s	remaining: 1.66s
# 84:	learn: 0.2798563	total: 8.79s	remaining: 1.55s
# 85:	learn: 0.2788050	total: 8.88s	remaining: 1.45s
# 86:	learn: 0.2779319	total: 8.99s	remaining: 1.34s
# 87:	learn: 0.2765982	total: 9.09s	remaining: 1.24s
# 88:	learn: 0.2754378	total: 9.18s	remaining: 1.14s
# 89:	learn: 0.2745344	total: 9.29s	remaining: 1.03s
# 90:	learn: 0.2735140	total: 9.39s	remaining: 929ms
# 91:	learn: 0.2723146	total: 9.49s	remaining: 825ms
# 92:	learn: 0.2714649	total: 9.6s	remaining: 722ms
# 93:	learn: 0.2708701	total: 9.69s	remaining: 619ms
# 94:	learn: 0.2697015	total: 9.79s	remaining: 516ms
# 95:	learn: 0.2686868	total: 9.9s	remaining: 412ms
# 96:	learn: 0.2678211	total: 10s	remaining: 309ms
# 97:	learn: 0.2670067	total: 10.1s	remaining: 206ms
# 98:	learn: 0.2660046	total: 10.2s	remaining: 103ms
# 99:	learn: 0.2652779	total: 10.3s	remaining: 0us
# model report:
#              model  train accuracy  test accuracy
# 0   Decision Tree        0.917420       0.877861
# 1       Ada Boost        0.580773       0.565647
# 2  Gradient Boost        0.946693       0.902674
# 3   Random Forest        0.991868       0.896411
# 4      KNeighbors        1.000000       0.749940
# 5       Cat Boost        0.916456       0.893038
# 6         XGBoost        0.970967       0.900506
# best model based on train accuracy:
#          model  train accuracy  test accuracy
# 4  KNeighbors             1.0        0.74994
# best model based on test accuracy:
#              model  train accuracy  test accuracy
# 2  Gradient Boost        0.946693       0.902674
# overall best model:
#       model  train accuracy  test accuracy  over_all_score
# 6  XGBoost        0.970967       0.900506        0.935737
# best model score: 0.9005059021922428
# best model name: XGBoost

# %%
'''
model report: 
             model  train accuracy  test accuracy
0   Decision Tree        0.918945       0.869942
1       Ada Boost        0.592436       0.590800
2  Gradient Boost        0.946766       0.903179
3   Random Forest        0.990847       0.899326
4      KNeighbors        1.000000       0.744942
5       Cat Boost        0.914669       0.903902
6         XGBoost        0.970733       0.903420
best model based on train accuracy: 
         model  train accuracy  test accuracy
4  KNeighbors             1.0       0.744942
best model based on test accuracy: 
         model  train accuracy  test accuracy
4  KNeighbors             1.0       0.744942
'''
# Out:
# '\nmodel report: \n             model  train accuracy  test accuracy\n0   Decision Tree        0.918945       0.869942\n1       Ada Boost        0.592436       0.590800\n2  Gradient Boost        0.946766       0.903179\n3   Random Forest        0.990847       0.899326\n4      KNeighbors        1.000000       0.744942\n5       Cat Boost        0.914669       0.903902\n6         XGBoost        0.970733       0.903420\nbest model based on train accuracy: \n         model  train accuracy  test accuracy\n4  KNeighbors             1.0       0.744942\nbest model based on test accuracy: \n         model  train accuracy  test accuracy\n4  KNeighbors             1.0       0.744942\n'

# %%
val = [0.918945 / 0.869942, 0.592436 / 0.590800, 0.946766 / 0.903179, 0.990847 / 0.899326, 1.000000 / 0.744942, 0.914669 / 0.903902, 0.970733 / 0.903420]

# %%
val
# Out:
# [1.0563290426258303,
#  1.0027691266079892,
#  1.048259536592414,
#  1.1017662115851206,
#  1.3423863871281254,
#  1.0119116895415654,
#  1.074509087689004]

# %%
reportt = {
    'model': ['Decision Tree', 'Ada Boost', 'Gradient Boost', 'Random Forest', 'KNeighbors', 'Cat Boost', 'XGBoost',],
    'train accuracy': [0.918945, 0.592436, 0.946766, 0.990847, 1.000000, 0.914669, 0.970733],
    'test accuracy': [0.869942, 0.590800, 0.903179, 0.899326, 0.744942, 0.903902, 0.903420]
}

dff = pd.DataFrame(reportt)
dff['over_all_score'] = (dff['train accuracy'] + dff['test accuracy']) / 2

dff
# Out:
#             model  train accuracy  test accuracy  over_all_score
# 0   Decision Tree        0.918945       0.869942        0.894443
# 1       Ada Boost        0.592436       0.590800        0.591618
# 2  Gradient Boost        0.946766       0.903179        0.924972
# 3   Random Forest        0.990847       0.899326        0.945086
# 4      KNeighbors        1.000000       0.744942        0.872471
# 5       Cat Boost        0.914669       0.903902        0.909285
# 6         XGBoost        0.970733       0.903420        0.937076

# %%
above_nine = dff[(dff['train accuracy'] > 0.9) & (dff['test accuracy'] > 0.9)]
best_model_record = above_nine[above_nine['over_all_score'] == above_nine['over_all_score'].max()]
best_model_record
# Out:
#      model  train accuracy  test accuracy  over_all_score
# 6  XGBoost        0.970733        0.90342        0.937076
